# %%
#import statements
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
#importing the data into the notebook
train_data = pd.read_csv("train.csv")
train_data.shape
# Out:
# (647054, 7)

# %%
#Checking structure of data
train_data.head()
# Out:
#    TripType  VisitNumber Weekday          Upc  ScanCount  \
# 0       999            5  Friday  68113152929         -1
# 1        30            7  Friday  60538815980          1
# 2        30            7  Friday   7410811099          1
# 3        26            8  Friday   2238403510          2
# 4        26            8  Friday   2006613744          2
#
#    DepartmentDescription  FinelineNumber
# 0     FINANCIAL SERVICES            1000
# 1                  SHOES            8931
# 2          PERSONAL CARE            4504
# 3  PAINT AND ACCESSORIES            3565
# 4  PAINT AND ACCESSORIES            1017

# %%
#Data Cleaning
#Checking Count of each column
print train_data.count()
#It showed there are some missing values in some rows.
#So missing rows can be removed considering the scale of data available.
train_data=train_data.dropna()
print train_data.count()
#Checking the unique values in each column.
print train_data.T.apply(lambda x: x.nunique(),axis=1)
# Out:
# TripType                 647054
# VisitNumber              647054
# Weekday                  647054
# Upc                      642925
# ScanCount                647054
# DepartmentDescription    645693
# FinelineNumber           642925
# dtype: int64
# TripType                 642925
# VisitNumber              642925
# Weekday                  642925
# Upc                      642925
# ScanCount                642925
# DepartmentDescription    642925
# FinelineNumber           642925
# dtype: int64
# TripType                    38
# VisitNumber              94247
# Weekday                      7
# Upc                      97714
# ScanCount                   39
# DepartmentDescription       68
# FinelineNumber            5195
# dtype: int64

# %%
#splitting the data into training set and testing set
train, test = train_test_split(train_data, test_size = 0.2)
test=test.dropna()
train=train.dropna()
train_data = train
train_data.describe()
# Out:
#             TripType    VisitNumber           Upc      ScanCount  \
# count  514340.000000  514340.000000  5.143400e+05  514340.000000
# mean       58.323127   96232.546944  3.060428e+10       1.110341
# std       156.519153   55560.639830  9.128952e+10       0.700809
# min         3.000000       5.000000  8.340000e+02     -10.000000
# 25%        27.000000   49263.000000  3.400001e+09       1.000000
# 50%        39.000000   97253.000000  7.050102e+09       1.000000
# 75%        40.000000  144411.000000  3.004505e+10       1.000000
# max       999.000000  191347.000000  9.789706e+11      71.000000
#
#        FinelineNumber
# count   514340.000000
# mean      3730.395573
# std       2781.767040
# min          0.000000
# 25%       1404.000000
# 50%       3352.000000
# 75%       5501.000000
# max       9998.000000

# %%
#Data preprocesssing
#Transforming qualitative variables into quantitative
def transform(day,no):
    global train_data
    train_data=train_data.replace(day,no)
    return;
transform("Monday", 1)
transform("Tuesday", 2)
transform("Wednesday", 3)
transform("Thursday", 4)
transform("Friday", 5)
transform("Saturday", 6)
transform("Sunday", 7)

#Removing redundency in department description column
train_data=train_data.replace("MENS WEAR","MENSWEAR")

# %%
#The visitnumber will be repeating for each product you bought in the same visit.
#So removing the duplicate rows for the same triptype by grouping by visit number.

#ploting the histogram for the trip type 
data_tripty = train_data.drop_duplicates("VisitNumber")
plt.figure(figsize=(12,5))
data_tripty['TripType'].value_counts().plot('bar',title="Visit Number Histogram")

# %%
#ploting the histogram for scancount.
plt.figure(figsize=(12,5))
train_data['ScanCount'].value_counts().plot('bar',logy='True',title="Scan Count Histogram")

# %%
#ploting histogram for daywise visits
plt.figure(figsize=(12,5))
train_data['Weekday'].value_counts().plot('bar',title="Daywise visits in a week ")

# %%
#DepartmentDescription Histogram.
plt.figure(figsize=(12,5))
train_data['DepartmentDescription'].value_counts().plot('bar',title="DepartmentDescription Histogram")

# %%
#Checking Whats inside the most frequent trip type 8 by plotting histogram.
trip_8 = train_data[train_data.TripType == 8]
trip_8_plot = trip_8[["TripType","DepartmentDescription"]]
trip_8_plot.DepartmentDescription.value_counts().head(7).plot(kind="bar", rot=45, 
                                                              title="Trip Type 8")
#Bylooking at it looks like trip type 8 is general purpose visting covering every department

# %%
#Checking Whats inside the most frequent trip type 39 by plotting histogram.
trip_39 = train_data[train_data.TripType == 39]
trip_39_plot = trip_39[["TripType","DepartmentDescription"]]
trip_39_plot.DepartmentDescription.value_counts().head(6).plot(kind="bar", rot=45, 
                                                              title="Trip Type 39")
#Bylooking at it looks like trip type 39 is grocery shopping.

# %%
#Checking Whats inside the most frequent trip type 9 by plotting histogram.

trip_9 = train_data[train_data.TripType == 9]
trip_9_plot = trip_9[["TripType","DepartmentDescription"]]
trip_9_plot.DepartmentDescription.value_counts().head(6).plot(kind="bar", rot=45, 
                                                              title="Trip Type 9")
#Bylooking at it looks like trip type 39 is Men's shopping.

# %%
#Checking Whats inside the most frequent trip type 999 by plotting histogram.

trip_999 = train_data[train_data.TripType == 999]
trip_999_plot = trip_999[["TripType","DepartmentDescription"]]
trip_999_plot.DepartmentDescription.value_counts().head(7).plot(kind="bar", rot=45, 
                                                              title="Trip Type 999")
#Bylooking at it looks like trip type 999 emphasis on financial services and clothing.

# %%
#Checking Whats inside the most frequent trip type 40 by plotting histogram.


trip_40 = train_data[train_data.TripType == 40]
trip_40_plot = trip_40[["TripType","DepartmentDescription"]]
trip_40_plot.DepartmentDescription.value_counts().head(6).plot(kind="bar", rot=45, 
                                                              title="Trip Type 40")
#Bylooking at it looks like trip type 40 emphasis on grocery .

# %%
#Checking Whats inside the most frequent trip type 7 by plotting histogram.

trip_7 = train_data[train_data.TripType == 7]
trip_7_plot = trip_7[["TripType","DepartmentDescription"]]
trip_7_plot.DepartmentDescription.value_counts().head(6).plot(kind="bar", rot=45, 
                                                              title="Trip Type 7")
#By looking at it looks like trip type 7 is complete grocery trip .

# %%
#Checking Whats inside the most frequent trip type 25 by plotting histogram.

trip_25 = train_data[train_data.TripType == 25]
trip_25_plot = trip_25[["TripType","DepartmentDescription"]]
trip_25_plot.DepartmentDescription.value_counts().head(6).plot(kind="bar", rot=45, 
                                                              title="Trip Type 25")
#By looking at it looks like trip type 25 is clothing trip.

# %%
#Checking Whats inside the most frequent trip type 3 by plotting histogram.

trip_3 = train_data[train_data.TripType == 3]
trip_3_plot = trip_3[["TripType","DepartmentDescription"]]
trip_3_plot.DepartmentDescription.value_counts().head(6).plot(kind="bar", rot=45, 
                                                              title="Trip Type 3")

#By looking at it looks like trip type 3 is financial services trip.

# %%
#Checking Whats inside the most frequent trip type 5 by plotting histogram.

trip_5 = train_data[train_data.TripType == 5]
trip_5_plot = trip_5[["TripType","DepartmentDescription"]]
trip_5_plot.DepartmentDescription.value_counts().head(6).plot(kind="bar", rot=45, 
                                                              title="Trip Type 5")
#By looking at it looks like trip type 5 is pharmacy trip.

# %%
#Checking Whats inside the most frequent trip type 36 by plotting histogram.


trip_36 = train_data[train_data.TripType == 36]
trip_36_plot = trip_36[["TripType","DepartmentDescription"]]
trip_36_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 36")

#By looking at it looks like trip type 36 is personal care trip.

# %%
#Checking Whats inside the most frequent trip type 38 by plotting histogram.

trip_38 = train_data[train_data.TripType == 38]
trip_38_plot = trip_38[["TripType","DepartmentDescription"]]
trip_38_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 38")
#By looking at it looks like trip type 38 is dairy based grocery trip.

# %%
#Checking Whats inside the most frequent trip type 37 by plotting histogram.

trip_37 = train_data[train_data.TripType == 37]
trip_37_plot = trip_37[["TripType","DepartmentDescription"]]
trip_37_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 37")

#By looking at it looks like trip type 37 is vegetable based grocery trip.

# %%
#Checking Whats inside the most frequent trip type 24 by plotting histogram.


trip_24 = train_data[train_data.TripType == 24]
trip_24_plot = trip_24[["TripType","DepartmentDescription"]]
trip_24_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 24")
#By looking at it looks like trip type 24 is home shopping.

# %%
#Checking Whats inside the most frequent trip type 35 by plotting histogram.


trip_35 = train_data[train_data.TripType == 35]
trip_35_plot = trip_35[["TripType","DepartmentDescription"]]
trip_35_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 35")
#By looking at it looks like trip type 35 is another grocery shopping.

# %%
#Checking Whats inside the most frequent trip type 32 by plotting histogram.

trip_32 = train_data[train_data.TripType == 32]
trip_32_plot = trip_32[["TripType","DepartmentDescription"]]
trip_32_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 32")
#By looking at it looks like trip type 32 is baby shopping.

# %%
#Checking Whats inside the most frequent trip type 42 by plotting histogram.

trip_42 = train_data[train_data.TripType == 42]
trip_42_plot = trip_42[["TripType","DepartmentDescription"]]
trip_42_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 42")
#By looking at it looks like trip type 42 is shopping .

# %%
#Checking Whats inside the most frequent trip type 33 by plotting histogram.

trip_33 = train_data[train_data.TripType == 33]
trip_33_plot = trip_33[["TripType","DepartmentDescription"]]
trip_33_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 33")

#By looking at it looks like trip type 33 is household supplies shopping .

# %%
#Checking Whats inside the most frequent trip type 6 by plotting histogram.

trip_6 = train_data[train_data.TripType == 6]
trip_6_plot = trip_6[["TripType","DepartmentDescription"]]
trip_6_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 6")
#By looking at it looks like trip type 6 is liquor and tobacco shopping .

# %%
#Checking Whats inside the most frequent trip type 44 by plotting histogram.

trip_44 = train_data[train_data.TripType == 44]
trip_44_plot = trip_44[["TripType","DepartmentDescription"]]
trip_44_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 44")
#By looking at it looks like trip type 44 is general purpose shopping .

# %%
#Checking Whats inside the most frequent trip type 30 by plotting histogram.

trip_30 = train_data[train_data.TripType == 30]
trip_30_plot = trip_30[["TripType","DepartmentDescription"]]
trip_30_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 30")
#By looking at it looks like trip type 30 is clothing and footwear shopping .

# %%
#Checking Whats inside the most frequent trip type 15 by plotting histogram.

trip_15 = train_data[train_data.TripType == 15]
trip_15_plot = trip_15[["TripType","DepartmentDescription"]]
trip_15_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 15")
#By looking at it looks like trip type 15 is party shopping .

# %%
#Checking Whats inside the most frequent trip type 22 by plotting histogram.

trip_22 = train_data[train_data.TripType == 22]
trip_22_plot = trip_22[["TripType","DepartmentDescription"]]
trip_22_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 22")
#By looking at it looks like trip type 22 is electronics shopping .

# %%
#Checking Whats inside the most frequent trip type 43 by plotting histogram.

trip_43 = train_data[train_data.TripType == 43]
trip_43_plot = trip_43[["TripType","DepartmentDescription"]]
trip_43_plot.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                                              title="Trip Type 43")
#By looking at it looks like trip type 43 is personal care shopping .
